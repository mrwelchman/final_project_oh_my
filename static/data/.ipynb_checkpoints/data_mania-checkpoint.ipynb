# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('nba_games.csv')
data.head()
# Out:
#                        Date Full Name (Data.Home Team)  \
# 0  2020-12-22T00:00:00.000Z              Brooklyn Nets
# 1  2020-12-22T00:00:00.000Z         Los Angeles Lakers
# 2  2020-12-25T00:00:00.000Z                 Miami Heat
# 3  2020-12-26T00:00:00.000Z         Washington Wizards
# 4  2020-12-23T00:00:00.000Z        Cleveland Cavaliers
#
#   Full Name (Data.Visitor Team)  Home Team Score  Visitor Team Score
# 0         Golden State Warriors              125                  99
# 1                   LA Clippers              109                 116
# 2          New Orleans Pelicans              111                  98
# 3                 Orlando Magic              120                 130
# 4             Charlotte Hornets              121                 114

# %%
nba2020 = data.rename(columns={'Full Name (Data.Home Team)':'Home Team', 'Full Name (Data.Visitor Team)':'Visitor Team'})
nba2020.to_csv('nba2020.csv')

# %%
nba2020['Point Difference'] = nba2020['Home Team Score']-nba2020['Visitor Team Score']

# %%
nba2020['Home Win'] = np.where(nba2020['Point Difference'] > 0, 1, 0)
nba2020['Home Loss'] = np.where(nba2020['Point Difference'] < 0, 1, 0)
nba2020.drop(columns=['home_win', 'home_loss'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-e47de16b28d9> in <module>
#       1 nba2020['Home Win'] = np.where(nba2020['Point Difference'] > 0, 1, 0)
#       2 nba2020['Home Loss'] = np.where(nba2020['Point Difference'] < 0, 1, 0)
# ----> 3 nba2020.drop(columns=['home_win', 'home_loss'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
df_visitor = pd.get_dummies(nba2020['Visitor Team'], dtype=np.int64)
df_home = pd.get_dummies(nba2020['Home Team'], dtype=np.int64)

# %%
df_model = df_home.sub(df_visitor) 
df_model['Point Difference'] = nba2020['Point Difference']

# %%
df_model.head()

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import Ridge

# %%
df_train = df_model 

lr = Ridge(alpha=0.001) 
X = df_train.drop(['Point Difference'], axis=1)
y = df_train['Point Difference']

lr.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bc91d669e9b6> in <module>
# ----> 1 df_train = df_model
#       2
#       3 lr = Ridge(alpha=0.001)
#       4 X = df_train.drop(['Point Difference'], axis=1)
#       5 y = df_train['Point Difference']
#
# NameError: name 'df_model' is not defined

# %%
df_ratings = pd.DataFrame(data={'team': X.columns, 'rating': lr.coef_})
df_ratings
# Out:
#                       team     rating
# 0            Atlanta Hawks   2.205903
# 1           Boston Celtics   1.317621
# 2            Brooklyn Nets   5.331597
# 3        Charlotte Hornets  -2.254194
# 4            Chicago Bulls  -0.934875
# 5      Cleveland Cavaliers  -8.241444
# 6         Dallas Mavericks   2.480117
# 7           Denver Nuggets   4.790087
# 8          Detroit Pistons  -4.374829
# 9    Golden State Warriors   1.019226
# 10         Houston Rockets  -7.505012
# 11          Indiana Pacers  -0.170850
# 12             LA Clippers   5.789548
# 13      Los Angeles Lakers   3.029545
# 14       Memphis Grizzlies   1.335345
# 15              Miami Heat  -0.803154
# 16         Milwaukee Bucks   5.666647
# 17  Minnesota Timberwolves  -5.251709
# 18    New Orleans Pelicans  -0.145111
# 19         New York Knicks   2.070932
# 20   Oklahoma City Thunder -10.131644
# 21           Orlando Magic  -9.014767
# 22      Philadelphia 76ers   5.404578
# 23            Phoenix Suns   5.400428
# ...

# %%
df_ratings.to_csv('team_ratings.csv')

# %%
nba2020=nba2020.drop(columns=['home_win', 'home_loss'])
nba2020
# Out:
#                           Date            Home Team           Visitor Team  \
# 0     2020-12-22T00:00:00.000Z        Brooklyn Nets  Golden State Warriors
# 1     2020-12-22T00:00:00.000Z   Los Angeles Lakers            LA Clippers
# 2     2020-12-25T00:00:00.000Z           Miami Heat   New Orleans Pelicans
# 3     2020-12-26T00:00:00.000Z   Washington Wizards          Orlando Magic
# 4     2020-12-23T00:00:00.000Z  Cleveland Cavaliers      Charlotte Hornets
# ...                        ...                  ...                    ...
# 1107  2021-03-25T00:00:00.000Z     Sacramento Kings  Golden State Warriors
# 1108  2021-04-09T00:00:00.000Z      Milwaukee Bucks      Charlotte Hornets
# 1109  2021-03-26T00:00:00.000Z      Detroit Pistons          Brooklyn Nets
# 1110  2021-03-27T00:00:00.000Z      Milwaukee Bucks        New York Knicks
# 1111  2021-03-28T00:00:00.000Z    Charlotte Hornets           Phoenix Suns
#
# ...

# %%
nba2020.to_csv('full_2020_season.csv')
